# %% [markdown]
# # Graded Assignment 1 :
# #### Ayesha Memon

# %% [markdown]
# <div style="text-align: center; margin-top: 20px;">
#   <img src="https://datasportsgroup.com/images/news/65855.png"
#        alt="Sabermetrics Dashboard"
#        style="width:85%; border: 4px solid #d4a5a5; border-radius: 12px; box-shadow: 4px 4px 12px #aaa;">
#   <p style="font-style: italic; font-size: 16px; color: #6a4e4e; margin-top: 10px;">
#     🏅 Hidden Olympic Story — A Data Perspective
#   </p>
# </div>

# %% [markdown]
# **Requirements:**
#
# Datacleaning part:
#
# Objective Part:
# - 5 Objective Questions
#
# Subjective Part:
# - 3 Subjective Questions (From your Brain - Make sure they are worthy to ask, Don't ask Repititve Question from Objective Section), and also must be unique question.
#
# Challenge Questions
# - 3 Challenge Questions
#
#
# Good luck!

# %% [markdown]
# ### Data Cleaning Section :

# %%
import pandas as pd

df = pd.read_csv("athlete_events.csv")

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.shape
# Out:
# (271116, 15)

# %% [markdown]
# #### 1. Remove duplicates

# %%
df.duplicated().any()
# Out:
# np.True_

# %%
df.duplicated().sum()
# Out:
# np.int64(1385)

# %%
df[df.duplicated()]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1252       704                   Dsir Antoine Acket   M  27.0     NaN     NaN
# 4282      2449               William Truman Aldrich   M  48.0     NaN     NaN
# 4283      2449               William Truman Aldrich   M  48.0     NaN     NaN
# 4862      2777               Hermann Reinhard Alker   M  43.0     NaN     NaN
# 4864      2777               Hermann Reinhard Alker   M  43.0     NaN     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 269994  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269995  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269997  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269999  135073   Doris Clare Zinkeisen (-Johnstone)   F  49.0     NaN     NaN
# 270200  135173                     Henri Achille Zo   M  58.0     NaN     NaN
#
# ...

# %%
before = df.shape[0]
df.drop_duplicates(inplace=True)
after = df.shape[0]
print(f" Removed {before - after} duplicate rows.")
# Out:
#  Removed 1385 duplicate rows.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### 2.Rename columns

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df.rename(columns={'Sex': 'Gender'}, inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Gender', 'Age', 'Height', 'Weight', 'Team', 'NOC',
#        'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df[['Gender']].head()
# Out:
#   Gender
# 0      M
# 1      M
# 2      M
# 3      M
# 4      F

# %%
df['Gender'] = df['Gender'].replace({'M': 'Male', 'F': 'Female'})
df['Gender']
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3           Male
# 4         Female
#            ...
# 271111      Male
# 271112      Male
# 271113      Male
# 271114      Male
# 271115      Male
# Name: Gender, Length: 269731, dtype: object

# %%
print("Missing before:", df['Medal'].isna().sum())
# Out:
# Missing before: 229959

# %%
df['Medal'] = df['Medal'].fillna('No Medal')
print(" Missing after:", df['Medal'].isna().sum())
# Out:
#  Missing after: 0

# %%
print(df['Medal'].value_counts().head())
# Out:
# Medal
# No Medal    229959
# Gold         13369
# Bronze       13295
# Silver       13108
# Name: count, dtype: int64

# %% [markdown]
# #### X---------------------------------END OF Cleaning DataSet---------------------------------------------X

# %% [markdown]
# #### OBJECTIVE QUESTIONS

# %% [markdown]
# ##### Q1: Which gender has won most medals across all Medal Categories?
# ### <span style="background-color:lightgreen">medals stats show male majority (early olympics might've needed a feminist edit jk)</span>

# %%
Medalists = df[df['Medal'] != 'No Medal']

gender_medal_counts = Medalists['Gender'].value_counts()

print(gender_medal_counts)
# Out:
# Gender
# Male      28519
# Female    11253
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

medal_winners = df[df['Medal'] != 'No Medal']

gender_medal_counts = medal_winners['Gender'].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(gender_medal_counts.index,
        gender_medal_counts.values,
        color=['#FFB6C1', '#ADD8E6']) 
<span style="background-color:pink">Out of curiosity</span>


plt.title(' Total Olympic Medals by Gender', fontsize=13, weight='bold')
plt.xlabel('Gender')
plt.ylabel('Number of Medals')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=0)
plt.tight_layout()

plt.show()
# Out:
# C:\Users\Muhammad Farooq\AppData\Local\Temp\ipykernel_25616\2996850728.py:25: UserWarning: Glyph 127894 (\N{MILITARY MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Program Files\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127894 (\N{MILITARY MEDAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##### Q2: Which country has won the most gold medals? Put Top 5

# %%
Nations_gold = df[df['Medal'] == 'Gold']

top5_gold = Nations_gold['Team'].value_counts().head(5)

print(top5_gold)
# Out:
# Team
# United States    2474
# Soviet Union     1058
# Germany           679
# Italy             535
# Great Britain     519
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Filter Gold Medal winners
gold_medals = df[df['Medal'] == 'Gold']

# Count top 5 countries
top5_gold = gold_medals['Team'].value_counts().head(5)

# Set figure
plt.figure(figsize=(8, 5))
ax = plt.gca()
ax.set_facecolor('#FFF0F5')  

# Plot with girly color combo
bars = plt.bar(top5_gold.index,
               top5_gold.values,
               color='purple',
               edgecolor='#B76E79',  
               linewidth=1.5)

# Add labels and title
plt.title(' Top 5 Countries by Gold Medals ', fontsize=15, weight='bold', color='#B76E79')
plt.xlabel('Country', fontsize=12, color='#555')
plt.ylabel('Number of Gold Medals', fontsize=12, color='#555')
plt.xticks(rotation=30, fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.5)

for i, value in enumerate(top5_gold):
    plt.text(i, value + 2, str(value), ha='center', fontsize=11, color='#B76E79', weight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Q3: What is the trend of Number of Participants in Each Olympic Years?

# %%
## Python Pandas Solution
unique_participants = df.drop_duplicates(subset=['Name', 'Year'])

# Count participants per year
participants_per_year = unique_participants['Year'].value_counts().sort_index()
participants_per_year.head(12)
# Out:
# Year
# 1896     176
# 1900    1220
# 1904     650
# 1906     841
# 1908    2024
# 1912    2409
# 1920    2675
# 1924    3565
# 1928    3702
# 1932    2174
# 1936    5138
# 1948    5068
# Name: count, dtype: int64

# %% [markdown]
# ## 📰 Olympic Participation (1896–1948): A Snapshot of Global Momentum
#
# From just **176 athletes in 1896**, the Olympics rapidly scaled to **5,138 by 1936**.
#
# **1936 Berlin** marked a peak—not just in size but symbolism—as Nazi Germany used it for propaganda.
#
# **1932** saw a sharp dip due to the **Great Depression**(prolonged economic recession),
#
# **WWII halted the Games** in 1940 & 1944.
#
# Yet in **1948**, post-war London nearly matched Berlin’s size, signaling **resilience and the rebirth of global unity** through sport.

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 6))
ax = plt.gca()
ax.set_facecolor('#FFF0F5')  


participants_per_year.plot(
    kind='line',
    marker='o',
    linestyle='-',
    color='#FF69B4',        
    markerfacecolor='#FFD1DC',  
    markeredgecolor='#C71585',  
    linewidth=2,
    markersize=8
)


plt.title(' Trend of Olympic Participants (1896–1948)', fontsize=15, weight='bold', color='#B76E79')
plt.xlabel('Year', fontsize=12, color='#555')
plt.ylabel('Unique Participants', fontsize=12, color='#555')

# Style the grid and ticks
plt.grid(True, linestyle='--', alpha=0.4)
plt.xticks(color='#444')
plt.yticks(color='#444')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Q4: Which Sport had Highest share of Silver Medals in 2014 Olympics?

# %% [markdown]
# ### <span style="color:teal">Ice Hockey topped the silver medal count in 2014 — not because it had more events, but because it’s a team sport so a single silver medal game can award over 40 individual medals. The numbers are real — but context is everything.</span>

# %%
silver_2014 = df[(df['Year'] == 2014) & (df['Medal'] == 'Silver')]
silver_by_sport = silver_2014['Sport'].value_counts()
top_silver_sport = silver_by_sport.idxmax()
top_silver_count = silver_by_sport.max()

print("Top 5 Sports with Most Silver Medals in 2014:\n")
silver_by_sport.head()
# Out:
# Top 5 Sports with Most Silver Medals in 2014:
# Sport
# Ice Hockey              43
# Biathlon                20
# Cross Country Skiing    20
# Speed Skating           17
# Figure Skating          15
# Name: count, dtype: int64

# %%
## Relevant Visualization Using Python
import matplotlib.pyplot as plt

# Prepare data
top5_silver = silver_by_sport.head(5)

# Custom pastel colors
colors = ['#FFC0CB', '#FFB6C1', '#FFD1DC', '#E6E6FA', '#ADD8E6']

# Create figure
plt.figure(figsize=(10, 6))
ax = plt.gca()
ax.set_facecolor('#FFF0F5')  # Soft background (lavender blush)

# Plot bars
bars = plt.bar(top5_silver.index,
               top5_silver.values,
               color=colors,
               edgecolor='gray',
               linewidth=1.2)

# Add value labels on top
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2,
             height + 0.5,
             f'{int(height)}',
             ha='center',
             va='bottom',
             fontsize=11,
             color='#8B5E83',  # Rosewood tone
             weight='bold')

# Titles and labels
plt.title('🥈 Top 5 Sports by Silver Medals — 2014 Olympics', fontsize=15, weight='bold', color='#B76E79')
plt.xlabel('Sport', fontsize=12, color='#444')
plt.ylabel('Number of Silver Medals', fontsize=12, color='#444')


plt.xticks(rotation=30, fontsize=11, color='#555')
plt.yticks(fontsize=11, color='#555')
plt.grid(axis='y', linestyle='--', alpha=0.4)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Muhammad Farooq\AppData\Local\Temp\ipykernel_25616\243531979.py:44: UserWarning: Glyph 129352 (\N{SECOND PLACE MEDAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()

# %% [markdown]
# ##### Q5: What is the distribution of age for each medal type excluding "No Medal"

# %%
# Filter out 'No Medal' entries
medalists = df[df['Medal'] != 'No Medal']

# Drop rows with missing Age values
medalists = medalists.dropna(subset=['Age'])

# Group by Medal and describe the Age statistics
age_distribution = medalists.groupby('Medal')['Age'].describe()

print(age_distribution)
# Out:
#           count       mean       std   min   25%   50%   75%   max
# Medal
# Bronze  13006.0  25.879210  5.831923  10.0  22.0  25.0  29.0  72.0
# Gold    13222.0  25.900015  5.892745  13.0  22.0  25.0  29.0  64.0
# Silver  12816.0  25.991495  6.008059  11.0  22.0  25.0  29.0  73.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Filter out rows with "No Medal"
medalists = df[df['Medal'] != 'No Medal']

# Step 2: Drop rows with missing age values
medalists = medalists.dropna(subset=['Age'])

# Step 3: Set Seaborn style
sns.set_style("whitegrid")  # Clean, minimal background

# Step 4: Violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(
    data=medalists,
    x='Medal',
    y='Age',
    palette='Set2',
    order=['Gold', 'Silver', 'Bronze'],
    inner='quartile'  # Show median and quartiles inside the violin
)

# Step 5: Title and labels
plt.title('🎻 Age Distribution by Medal Type', fontsize=16, weight='bold')
plt.xlabel('Medal', fontsize=12)
plt.ylabel('Age', fontsize=12)
plt.grid(True, axis='y', linestyle='--', alpha=0.4)
plt.tight_layout()

# Step 6: Show it
plt.show()
# Out:
# C:\Users\Muhammad Farooq\AppData\Local\Temp\ipykernel_25616\4196003393.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# C:\Users\Muhammad Farooq\AppData\Local\Temp\ipykernel_25616\4196003393.py:29: UserWarning: Glyph 127931 (\N{VIOLIN}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Program Files\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127931 (\N{VIOLIN}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# <span style="color:green; background-color:yellow;"><em>
# ✅ This violin plot shows the age distribution of Olympic medalists (excluding "No Medal").
#
# - Most winners are between 22 and 29 years old.
# - Gold, Silver, and Bronze medalists have similar median ages (~25).
# - Silver shows slightly more variation in age.
# - Some outliers were as young as 10 or as old as 70+.
#
# 🎯 Age alone doesn’t determine medal type — most winners peak in the same age window.
# </em></span>

# %% [markdown]
# ### X--------------------------------- END OF Objective Questions ---------------------------------------------X

# %% [markdown]
# Now Brain Storm 3 More Questions and Format Notebook in the same way like above

# %% [markdown]
# #### SUBJECTIVE QUESTIONS
#
# ## <span style="background-color:pink">Real Investigation of dataset By Sherlock :)</span>

# %% [markdown]
# ### Q3 -> "What does the average gold/silver/bronze-winning athlete look like (age, height, weight, **BMI**) per sport?"

# %% [markdown]
# <div style="background-color: #fff9c4; padding: 5px; border-left: 5px solid #fdd835; font-size: 14px; color: #3e2723; line-height: 1.2;">
#
# <h3 style="margin-top:0; color:#f57f17;">🏅 The Olympic Body Blueprint</h3>
#
# <b>Every Olympic sport demands a unique kind of body</b> — a hidden blueprint of success coded in <b>age</b>, <b>height</b>, <b>weight</b>, and <b>BMI</b>.
# What if we could <span style="background-color:#ffeb3b;">reverse-engineer this?</span>
#
#
# By analyzing thousands of Olympic medalists, I've uncovered the <b>ideal physical profile</b> for each sport.
# The result is not just data — it’s a <span style="background-color:#ffe082;"><b>playbook for peak performance</b></span>.
#
#
# Whether you're <b>building national teams</b>, <b>scouting rising stars</b>, or <b>developing training programs</b>,
# this is your shortcut to <span style="color:#d84315;"><b>smart, science-backed decisions</b></span>.
#
# </div>

# %%
import pandas as pd

# Load and merge data
df = pd.read_csv("athlete_events.csv")
noc = pd.read_csv("noc_regions.csv")
df = df.merge(noc, on='NOC', how='left')

# Drop missing values
df = df.dropna(subset=['Age', 'Height', 'Weight', 'Medal'])

# Add BMI column
df['BMI'] = df['Weight'] / (df['Height']/100)**2

# Group by Sport and Medal and calculate averages
ideal_profile = df.groupby(['Sport', 'Medal'])[['Age', 'Height', 'Weight', 'BMI']].mean().reset_index()

# Optional: Round for clean display
ideal_profile = ideal_profile.round(1)

# Display top 10 for example
print(ideal_profile)
# Out:
#              Sport   Medal   Age  Height  Weight   BMI
# 0    Alpine Skiing  Bronze  24.5   173.6    73.1  24.1
# 1    Alpine Skiing    Gold  24.2   173.9    72.8  23.9
# 2    Alpine Skiing  Silver  24.8   173.5    72.4  23.9
# 3          Archery  Bronze  25.2   173.4    71.2  23.5
# 4          Archery    Gold  24.0   173.8    71.1  23.4
# ..             ...     ...   ...     ...     ...   ...
# 155  Weightlifting    Gold  25.1   166.7    81.3  28.5
# 156  Weightlifting  Silver  24.7   167.8    81.2  28.3
# 157      Wrestling  Bronze  26.2   172.7    77.2  25.4
# 158      Wrestling    Gold  25.6   172.7    76.3  25.1
# 159      Wrestling  Silver  25.9   172.9    76.5  25.2
#
# [160 rows x 6 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample of your summarized data (simulated for demo)
data = {
    'Sport': [
        'Alpine Skiing', 'Archery', 'Boxing', 'Gymnastics', 'Judo', 'Rowing', 'Swimming', 'Weightlifting', 'Wrestling'
    ],
    'Age': [24.5, 24.4, 23.9, 21.3, 25.7, 26.5, 22.9, 25.1, 25.9],
    'Height': [173.6, 173.6, 176.1, 162.3, 175.0, 185.2, 183.7, 166.7, 172.7],
    'Weight': [73.1, 71.2, 72.0, 58.5, 75.3, 82.1, 74.5, 81.3, 77.2],
    'BMI': [24.1, 23.5, 23.2, 22.2, 24.6, 23.9, 22.1, 28.5, 25.4]
}

df = pd.DataFrame(data)
df.set_index('Sport', inplace=True)

# Plot: Heatmap to compare Age, Height, Weight, BMI across sports
plt.figure(figsize=(14, 8))
sns.heatmap(df, annot=True, fmt=".1f", cmap="YlGnBu", cbar_kws={'label': 'Metric Value'})
plt.title("The Ideal Olympian: Physical Profile by Sport", fontsize=16, weight='bold')
plt.ylabel("Sport")
plt.xlabel("Attribute")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q1: "The Great Olympic Vanish" : Which Nations Suffered the Most Dramatic Medal Drops?

# %% [markdown]
# <div style="background-color: #fff3cd; padding: 15px; border-left: 6px solid #f0ad4e; font-style: italic; font-size: 15px; line-height: 1.1; color: #333;">
#
# <b>This analysis uncovers a historically significant pattern:</b> the massive medal drop wasn’t due to poor performance, but rather to larger global events.
#
# <br><br>
#
# <span style="color: green;"><b>📉 The Soviet Union’s absence from the 1984 Los Angeles Olympics</b></span> wasn't just a random skip — <span style="color: crimson;"><b>they boycotted</b></span> the Games due to <b style="color: navy;">Cold War</b> tensions.
#
# <br><br>
#
# <b style="color: darkred;">No participation = nearly no medals.</b>
#
# <br><br>
#
# This wasn’t just sports — <span style="color: #0d6efd;"><b>it was geopolitics on display.</b></span>
#
# </div>

# %%
# Step 1: Medal winners only
df = pd.read_csv("athlete_events.csv")
medal_data = df[df['Medal'] != 'No Medal']

# Step 2: Count medals per country and year
medals_by_team_year = medal_data.groupby(['Team', 'Year'])['Medal'].count().reset_index()

# Step 3: Calculate difference between consecutive years per country
medals_by_team_year.sort_values(['Team', 'Year'], inplace=True)
medals_by_team_year['Medal_Change'] = medals_by_team_year.groupby('Team')['Medal'].diff()

# Step 4: Get most dramatic decline
largest_decline = medals_by_team_year.sort_values('Medal_Change').head(5)

print(largest_decline)
# Out:
#                Team  Year  Medal  Medal_Change
# 4259   Soviet Union  1984     44        -444.0
# 1366   East Germany  1984     19        -268.0
# 4844  United States  1998     30        -225.0
# 4850  United States  2010     89        -220.0
# 4842  United States  1994     19        -217.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    "Team": ["Soviet Union", "East Germany", "United States", "United States", "United States"],
    "Year": [1984, 1984, 1998, 2010, 1994],
    "Medal": [44, 19, 30, 89, 19],
    "Medal_Change": [-444.0, -268.0, -225.0, -220.0, -217.0]
}

df = pd.DataFrame(data)

# Hypothetical previous medals
df["Previous_Medal"] = [488, 287, 255, 309, 236]

# Assign unique colors per team
unique_teams = df["Team"].unique()
color_map = dict(zip(unique_teams, plt.cm.Set2.colors[:len(unique_teams)]))

# Sort for better label spacing
df.sort_values("Previous_Medal", ascending=False, inplace=True)

# Plot
plt.figure(figsize=(12, 8))
for i, row in df.iterrows():
    color = color_map[row["Team"]]
    plt.plot([0, 1], [row["Previous_Medal"], row["Medal"]],
             marker='o', color=color, linewidth=2.5)
    
    # Slight vertical offset for labels
    offset = 4
    plt.text(-0.05, row["Previous_Medal"] + offset,
             f'{row["Team"]} ({row["Year"] - 4})',
             ha='right', va='center', fontsize=9, color=color, weight='bold')
    
    plt.text(1.05, row["Medal"] + offset,
             f'{row["Team"]} ({row["Year"]})',
             ha='left', va='center', fontsize=9, color=color)

# Styling
plt.xticks([0, 1], ['Previous Olympics', 'Year with Drop'], fontsize=12, weight='bold')
plt.title("🎯 Most Dramatic Medal Declines in Olympic History", fontsize=16, weight='bold', color='#333333')
plt.ylabel("Medal Count", fontsize=12)
plt.grid(True, axis='y', linestyle='--', alpha=0.5)
plt.xlim(-0.3, 1.3)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Muhammad Farooq\AppData\Local\Temp\ipykernel_25616\1775379075.py:47: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Program Files\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Q#2 "Olympic ROI: Who Delivers the Most Medals per Athlete?

# %% [markdown]
# <div style="background-color: #e8f5e9; padding: 10px; border-left: 6px solid #43a047; font-style: italic; font-size: 15px; color: #1b5e20; line-height: 1.0;">
#
# <b>Some countries don’t need to send big teams to win big. 🧠🎯</b>
#
# <br><br>
#
# 🌍 <b>Example:</b>
# <ul>
#   <li><b>South Korea</b> in <b>Archery</b></li>
#   <li><b>Jamaica</b> in <b>Sprinting</b></li>
# </ul>
#
# They win many medals with just a few athletes — meaning they're <b>highly efficient</b>. They get more medals <b>per athlete</b> than many larger teams.
#
# <br><br>
#
# <b>Why this matters:</b>
# 🚀 It shows <b>smart planning beats big spending</b>.
#
# <br><br>
#
# <i>💡 Success isn’t about how many people you have — it’s about sending the right ones to the right place.</i>
#
# </div>

# %%
athletes_df = pd.read_csv("athlete_events.csv")
noc_df = pd.read_csv("noc_regions.csv")

# Merge region (country name) into main dataframe
df = athletes_df.merge(noc_df, how='left', on='NOC')

# Remove entries without a region (country)
df = df.dropna(subset=['region'])

# Step 1: Filter out athletes who didn’t win a medal
medal_df = df[df['Medal'].notna()]

# Step 2: Count unique athletes sent per Country + Sport
athletes_sent = df.groupby(['region', 'Sport'])['ID'].nunique().reset_index()
athletes_sent.rename(columns={'ID': 'Athletes_Sent'}, inplace=True)

# Step 3: Count medals won per Country + Sport
medals_won = medal_df.groupby(['region', 'Sport'])['Medal'].count().reset_index()
medals_won.rename(columns={'Medal': 'Medals_Won'}, inplace=True)

# Step 4: Merge and calculate medals per athlete
roi_df = pd.merge(athletes_sent, medals_won, on=['region', 'Sport'], how='left')
roi_df['Medals_Won'] = roi_df['Medals_Won'].fillna(0)
roi_df['Medals_per_Athlete'] = roi_df['Medals_Won'] / roi_df['Athletes_Sent']

# Optional: Filter to only show sports with a meaningful number of athletes
roi_df = roi_df[roi_df['Athletes_Sent'] >= 5]

# Step 5: Sort for analysis
roi_df = roi_df.sort_values(by='Medals_per_Athlete', ascending=False)
roi_df
# Out:
#            region                      Sport  Athletes_Sent  Medals_Won  \
# 2706       Russia                 Gymnastics            146       399.0
# 593        Canada  Short Track Speed Skating             36        70.0
# 184     Australia                   Softball             33        60.0
# 335       Belgium                    Archery             30        52.0
# 2952  South Korea                    Archery             41        69.0
# ...           ...                        ...            ...         ...
# 1764   Kazakhstan                   Canoeing             27         0.0
# 20        Algeria                    Cycling              6         0.0
# 21        Algeria                    Fencing             13         0.0
# 22        Algeria                   Football             32         0.0
# 24        Algeria                   Handball             45         0.0
#
#       Medals_per_Athlete
# 2706            2.732877
# 593             1.944444
# ...

# %%
plt.figure(figsize=(12, 9))
bars = plt.barh(top_roi['region'] + ' - ' + top_roi['Sport'], top_roi['Medals_per_Athlete'], color=plt.cm.viridis(top_roi['Medals_per_Athlete'] / max(top_roi['Medals_per_Athlete'])))
plt.xlabel('Medals per Athlete Sent', fontsize=12)
plt.title('🎯 Top 20 Most Medal-Efficient Country + Sport Combos (Olympic ROI)', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.xticks(fontsize=10)
plt.yticks(fontsize=9)
plt.tight_layout()

# Add value labels
for bar in bars:
    plt.text(bar.get_width() + 0.005, bar.get_y() + bar.get_height()/2,
             f"{bar.get_width():.2f}", va='center', fontsize=9, color='black')

plt.show()
# Out:
# C:\Users\Muhammad Farooq\AppData\Local\Temp\ipykernel_25616\1967901341.py:9: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Program Files\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd

# Load and merge data
df = pd.read_csv("athlete_events.csv")
noc = pd.read_csv("noc_regions.csv")
df = df.merge(noc, on='NOC', how='left')

# Drop missing values
df = df.dropna(subset=['Age', 'Height', 'Weight', 'Medal'])

# Add BMI column
df['BMI'] = df['Weight'] / (df['Height']/100)**2

# Group by Sport and Medal and calculate averages
ideal_profile = df.groupby(['Sport', 'Medal'])[['Age', 'Height', 'Weight', 'BMI']].mean().reset_index()

# Optional: Round for clean display
ideal_profile = ideal_profile.round(1)

# Display top 10 for example
print(ideal_profile)
# Out:
#              Sport   Medal   Age  Height  Weight   BMI
# 0    Alpine Skiing  Bronze  24.5   173.6    73.1  24.1
# 1    Alpine Skiing    Gold  24.2   173.9    72.8  23.9
# 2    Alpine Skiing  Silver  24.8   173.5    72.4  23.9
# 3          Archery  Bronze  25.2   173.4    71.2  23.5
# 4          Archery    Gold  24.0   173.8    71.1  23.4
# ..             ...     ...   ...     ...     ...   ...
# 155  Weightlifting    Gold  25.1   166.7    81.3  28.5
# 156  Weightlifting  Silver  24.7   167.8    81.2  28.3
# 157      Wrestling  Bronze  26.2   172.7    77.2  25.4
# 158      Wrestling    Gold  25.6   172.7    76.3  25.1
# 159      Wrestling  Silver  25.9   172.9    76.5  25.2
#
# [160 rows x 6 columns]

# %% [markdown]
# ### CHALLENGE QUESTIONS

# %% [markdown]
# ##### 1. Matching with List of Values
# Hence the Question is from Countries in Question 2 what are the Top 5 Athletes

# %%
df.head()
# Out:
#    ID                      Name  Gender   Age  Height  Weight            Team  \
# 0   1                 A Dijiang    Male  24.0   180.0    80.0           China
# 1   2                  A Lamusi    Male  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby    Male  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye    Male  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink  Female  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event     Medal
# 0       Basketball Men's Basketball  No Medal
# ...

# %%
top_countries = ['United States', 'Soviet Union', 'Germany', 'Great Britain', 'France']
filtered_df = df[df['Team'].isin(top_countries)]
top_athletes = (
    filtered_df[filtered_df['Medal'] != 'No Medal']
    .groupby(['Name', 'Team'])
    .size()
    .reset_index(name='Medal_Count')
    .sort_values(by='Medal_Count', ascending=False)
    .head(5)
)
top_athletes
# Out:
#                                       Name           Team  Medal_Count
# 5661               Michael Fred Phelps, II  United States           28
# 4813    Larysa Semenivna Latynina (Diriy-)   Soviet Union           18
# 6064          Nikolay Yefimovich Andrianov   Soviet Union           15
# 964            Borys Anfiyanovych Shakhlin   Soviet Union           13
# 1684  Dara Grace Torres (-Hoffman, -Minas)  United States           12

# %% [markdown]
# <span style="color:darkgreen; background-color:lightyellow; font-size:18px;"><em>
# 🏆 This chart is a salute to the greatest medal-winners in Olympic history.  .
# </em></span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data
data = {
    "Name": [
        "Michael Fred Phelps, II",
        "Larysa Semenivna Latynina (Diriy-)",
        "Nikolay Yefimovich Andrianov",
        "Borys Anfiyanovych Shakhlin",
        "Dara Grace Torres (-Hoffman, -Minas)"
    ],
    "Team": [
        "United States",
        "Soviet Union",
        "Soviet Union",
        "Soviet Union",
        "United States"
    ],
    "Medal_Count": [28, 18, 15, 13, 12]
}

df_top_athletes = pd.DataFrame(data)

# Set style
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

# Barplot with colors mapped to country
palette = {"United States": "#1f77b4", "Soviet Union": "#d62728"}
bars = sns.barplot(
    data=df_top_athletes,
    y="Name",
    x="Medal_Count",
    hue="Team",
    dodge=False,
    palette=palette
)

# Aesthetics
plt.title("🏅 Top 5 Most Decorated Olympians in History", fontsize=16, weight='bold')
plt.xlabel("Total Medals Won", fontsize=12)
plt.ylabel("Athlete", fontsize=12)
plt.legend(title="Team", loc="lower right")
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()

# Add medal count labels on bars
for i, row in df_top_athletes.iterrows():
    plt.text(row["Medal_Count"] + 0.5, i, str(row["Medal_Count"]), va='center', fontsize=10)

plt.show()
# Out:
# C:\Users\Muhammad Farooq\AppData\Local\Temp\ipykernel_25616\450073913.py:48: UserWarning: Glyph 127941 (\N{SPORTS MEDAL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Program Files\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127941 (\N{SPORTS MEDAL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##### 2. Getting Data within Range of Values
#
# ##### For Age Between 18 - 30 , Find the Top 5 Athlete by Number of Gold Medals Won.

# %% [markdown]
# <span style="color:purple; background-color:lightgreen;font-size:18px;"><em>
# This chart uncovers a rare breed of athletes who did'nt
# just peak — they exploded into Olympic history while still in their youth.*.
# </em></span>

# %%
age_filtered_gold = df[
    df['Age'].between(18, 30) & 
    (df['Medal'] == 'Gold')
]

top_5_young_gold = (
    age_filtered_gold.groupby(['Name', 'Team'])
    .size()
    .reset_index(name='Gold_Medal_Count')
    .sort_values(by='Gold_Medal_Count', ascending=False)
    .head(5)
)

top_5_young_gold

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for gold medalists aged 18–30
age_filtered_gold = df[
    df['Age'].between(18, 30) & 
    (df['Medal'] == 'Gold')
]

# Group by athlete name and team, count gold medals, and get top 5
top_5_young_gold = (
    age_filtered_gold.groupby(['Name', 'Team'])
    .size()
    .reset_index(name='Gold_Medal_Count')
    .sort_values(by='Gold_Medal_Count', ascending=False)
    .head(5)
)

# Set seaborn theme
sns.set_theme(style="whitegrid")

# Create figure
plt.figure(figsize=(10, 6))

# Plot horizontal bar chart
bars = sns.barplot(
    data=top_5_young_gold,
    y="Name",
    x="Gold_Medal_Count",
    hue="Team",
    dodge=False,
    palette="viridis"
)

# Add bar labels
for bar in bars.patches:
    bars.annotate(
        format(bar.get_width(), '.0f'),
        (bar.get_width() + 0.1, bar.get_y() + bar.get_height() / 2),
        va='center',
        fontsize=11,
        color='black'
    )

# Titles and labels
plt.title("Top 5 Young Olympic Gold Medalists (Age 18–30)", fontsize=14)
plt.xlabel("Gold Medals Won")
plt.ylabel("Athlete Name")
plt.legend(title="Team", loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3. Merging Data from Two Tables
#
# Oftenly it occurs, we have two CSVs one with the All the Data and the Other with Reference Data to Lookup, In our data we have Athletes with Short Country name, can you Show Country Names by Merging both CSVs and showing Country Names in Full instead of Acronyms
#
# Use: NOC_Regions.csv , Load it in Another data frame and Complete the task
#
# How to Merge two Tables in Pandas https://colab.research.google.com/github/amoreira2/Lectures/blob/main/chapters/pandas/merge.ipynb
#
# Or you can watch this helper Video : https://youtu.be/AHS925L8JVk
#
# ##### Question : Which Country has the tallest athletes in Latest Olympics? Display Top 5 (Country Names)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the datasets
df = pd.read_csv('athlete_events.csv')  
noc = pd.read_csv('noc_regions.csv')

# Merge the country names into the main DataFrame
df = pd.merge(df, noc, how='left', left_on='NOC', right_on='NOC')

# Rename for clarity
df.rename(columns={'region': 'Country'}, inplace=True)
\
df_height = df.dropna(subset=['Height'])

# Filter the latest Olympics year
latest_year = df_height['Year'].max()
latest_olympics = df_height[df_height['Year'] == latest_year]

# Group by Country and compute average height
top5_tallest = (
    latest_olympics.groupby('Country')['Height']
    .mean()
    .sort_values(ascending=False)
    .head(5)
    .reset_index()
)

top5_tallest.columns = ['Country', 'Average_Height']
print(top5_tallest)
# Out:
#               Country  Average_Height
# 0             Croatia      185.956989
# 1               Syria      185.333333
# 2  Virgin Islands, US      185.000000
# 3               Qatar      184.142857
# 4           Lithuania      184.137500

# %% [markdown]
# ### This chart reveals which nations consistently produce towering athletes, possibly due to training pipelines, athletic scouting, and sports specialization.
# These aren't just tall individuals — they're national sports assets.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set(style="whitegrid")

# Define a custom color palette (you can tweak this)
colors = sns.color_palette("viridis", len(top5_tallest))

# Create the plot
plt.figure(figsize=(12, 7))
bars = sns.barplot(
    data=top5_tallest,
    x='Country',
    y='Average_Height',
    palette=colors,
    edgecolor='black'
)

# Add data labels
for bar in bars.patches:
    height = bar.get_height()
    bars.annotate(
        f'{height:.1f} cm',
        (bar.get_x() + bar.get_width() / 2, height),
        ha='center', va='bottom',
        fontsize=11, fontweight='bold',
        color='black'
    )

# Titles
plt.title(
    "🏅 Top 5 Countries with Tallest Athletes (Latest Olympics)",
    fontsize=16, fontweight='bold'
)
plt.suptitle(
    "Average height comparison (in cm) | Which nations stand tallest?",
    fontsize=12, color='gray', y=0.93
)

# Axis labels
plt.xlabel('')
plt.ylabel('Average Height (cm)', fontsize=12)

# Remove top and right borders
sns.despine()

# Tidy layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Muhammad Farooq\AppData\Local\Temp\ipykernel_25616\4017950119.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bars = sns.barplot(
# C:\Users\Muhammad Farooq\AppData\Local\Temp\ipykernel_25616\4017950119.py:49: UserWarning: Glyph 127941 (\N{SPORTS MEDAL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Program Files\Python313\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127941 (\N{SPORTS MEDAL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ###### countries which only came once and never again ! is'nt it spooky??,aisha:))

# %%
country_medals_by_year = medal_df.groupby(['region', 'Year'])['Medal'].count().reset_index()
country_year_counts = country_medals_by_year.groupby('region')['Year'].count().reset_index()
one_hit_wonders = country_year_counts[country_year_counts['Year'] == 1]
one_hit_wonders
# Out:
#                  region  Year
# 9              Barbados     1
# 12              Bermuda     1
# 13             Botswana     1
# 25              Curacao     1
# 26               Cyprus     1
# 29             Djibouti     1
# 33              Eritrea     1
# 36                 Fiji     1
# 39                Gabon     1
# 45            Guatemala     1
# 46               Guyana     1
# 54                 Iraq     1
# 61               Jordan     1
# 64               Kosovo     1
# 72            Macedonia     1
# 74            Mauritius     1
# 77               Monaco     1
# 79           Montenegro     1
# 83                Nepal     1
# 92             Paraguay     1
# 102             Senegal     1
# 110               Sudan     1
# 117            Tanzania     1
# 119                Togo     1
# 120               Tonga     1
# 133  Virgin Islands, US     1

# %% [markdown]
# <div style="background-color:#fff0f5; padding: 20px; border-left: 6px solid #e75480; color:#4b0082; font-family: 'Georgia', serif; line-height: 1.8; font-size: 16px;">
#
# <h2 style="color:#e75480; margin-top:0;">🌷 Final Note – <i>Data Detective’s Diary</i></h2>
#
# <p><i>Thought I was just counting medals...</i><br>
# Instead, I uncovered <b>political drama</b>, <b>athletic elegance</b>, and nations vanishing like <span style="color:#c08081;"><i>whispers in time</i></span>.</p>
#
# <p>💡 <b>Lesson?</b> Every chart hides a secret.<br>
# And every secret needs a <span style="background-color:#ffe4e1; padding:2px 6px; border-radius:6px;">curious heart</span> to unveil it.</p>
#
# <p>🎯 <b>Mission complete.</b> Mind <i>Brain mildly fried.</i>. Curiosity <i>fully fed</i>.</p>
#
# <h3 style="color:#db7093;">✨ The game is data-field.</h3>
#
# <p style="margin-top: 25px; font-style: italic; color:#8b008b;">Until the next case…</p>
# <p style="text-align:right; font-style: italic; margin-top:5px;">— Yours analytically,<br> 💖</p>
#
# </div>
